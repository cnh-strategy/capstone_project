# %%
# 디베이트 테스트

# %%
# 맨 위 셀에 넣기
import sys
from pathlib import Path

# capstone_project 폴더를 찾아 sys.path 맨 앞에 추가
p = Path.cwd()
root = None
for q in [p, *p.parents]:
    if q.name == "capstone_project":
        root = q
        break

if root is None:
    # 노트북이 전혀 다른 곳에서 열렸다면 경로를 직접 지정
    root = Path(r"C:\Users\ska69\capstone_project")

sys.path.insert(0, str(root))
print("PROJECT ROOT:", root)

# 테스트
import prompts
from agents.technical_agent import TechnicalAgent
print("imports ok")
# Out:
# PROJECT ROOT: C:\Users\ska69\capstone_project
# imports ok

# %%
from agents.debate_agent import DebateAgent

debate_agent = DebateAgent(1, "NVDA")
# Out:
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# [SentimentalAgent] 모델 로드 스킵: SentimentalAgent._load_model_if_exists: model 초기화 실패

# %%
debate_agent.run_dataset()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [TechnicalAgent] X_seq: (981, 55, 13), y_seq: (981, 1)
# ✅ NVDA TechnicalAgent dataset saved to CSV (981 samples, 13 features)
# [MacroSentiAgent] X_seq: (1221, 14, 13), y_seq: (1221, 1)
# ✅ NVDA MacroSentiAgent dataset saved to CSV (1221 samples, 13 features)
# [SentimentalAgent] X_seq: (1195, 40, 8), y_seq: (1195, 1)
# ✅ NVDA SentimentalAgent dataset saved to CSV (1195 samples, 8 features)
# ✅ NVDA TechnicalAgent dataset saved via technical_data_set
# [TRACE B] macro_dataset() start for NVDA
# [*********************100%***********************]  15 of 15 completed
# [MacroSentimentAgent] Data shape: (1304, 90), Columns: 90
# [TRACE A] add_features() for self.data:            Open_CL=F  Open_DX-Y.NYB  Open_EURUSD=X    Open_GC=F  Open_HG=F  \
# Date
# 2020-01-01        NaN            NaN       1.122083          NaN        NaN
# 2020-01-02  61.599998      96.480003       1.121894  1518.099976     2.8165
# 2020-01-03  61.180000      96.790001       1.117081  1530.099976     2.7935
# 2020-01-06  63.709999      96.900002       1.116246  1580.000000     2.7780
# 2020-01-07  62.910000      96.650002       1.119583  1558.300049     2.8010
# ...               ...            ...            ...          ...        ...
# 2024-12-24  69.559998     108.160004       1.040583  2613.000000     4.0525
# 2024-12-25        NaN            NaN       1.040258          NaN        NaN
# 2024-12-26  70.199997     108.169998       1.039955  2628.500000     4.0730
# 2024-12-27  69.680000     108.080002       1.042318  2617.699951     4.0615
# 2024-12-30  70.419998     108.010002       1.042938  2620.699951     4.0900
#
#               Open_QQQ    Open_SPY  Open_USDJPY=X     Open_^DJI  Open_^FVX  \
# Date
# 2020-01-01         NaN         NaN     108.680000           NaN        NaN
# 2020-01-02  214.399994  323.540009     108.713997  28638.970703      1.683
# 2020-01-03  213.300003  321.160004     108.540001  28553.330078      1.622
# 2020-01-06  212.500000  320.489990     107.999001  28465.500000      1.591
# 2020-01-07  215.639999  323.019989     108.411003  28639.179688      1.596
# ...                ...         ...            ...           ...        ...
# 2024-12-24  524.830017  596.059998     157.164993  42916.480469      4.452
# 2024-12-25         NaN         NaN     157.106995           NaN        NaN
# 2024-12-26  528.320007  599.500000     157.132996  43201.851562      4.484
# 2024-12-27  526.010010  597.539978     157.748001  43142.371094      4.447
# 2024-12-30  515.510010  587.890015     157.873001  42863.859375      4.408
#
#             ...  Volume_QQQ  Volume_SPY  Volume_USDJPY=X  Volume_^DJI  \
# Date        ...
# 2020-01-01  ...         NaN         NaN              0.0          NaN
# 2020-01-02  ...  30969400.0  59151200.0              0.0  251820000.0
# 2020-01-03  ...  27518900.0  77709700.0              0.0  239590000.0
# 2020-01-06  ...  21655300.0  55653900.0              0.0  252760000.0
# 2020-01-07  ...  22139300.0  40496400.0              0.0  258900000.0
# ...         ...         ...         ...              ...          ...
# 2024-12-24  ...  17558200.0  33160100.0              0.0  230410000.0
# 2024-12-25  ...         NaN         NaN              0.0          NaN
# 2024-12-26  ...  19090500.0  41219100.0              0.0  270350000.0
# 2024-12-27  ...  33839600.0  64969300.0              0.0  376960000.0
# 2024-12-30  ...  34584000.0  56578800.0              0.0  383300000.0
#
#             Volume_^FVX  Volume_^GSPC  Volume_^IRX  Volume_^IXIC  Volume_^TNX  \
# Date
# 2020-01-01          NaN           NaN          NaN           NaN          NaN
# 2020-01-02          0.0  3.459930e+09          0.0  2.862700e+09          0.0
# 2020-01-03          0.0  3.484700e+09          0.0  2.586520e+09          0.0
# 2020-01-06          0.0  3.702460e+09          0.0  2.810450e+09          0.0
# 2020-01-07          0.0  3.435910e+09          0.0  2.381740e+09          0.0
# ...                 ...           ...          ...           ...          ...
# 2024-12-24          0.0  1.757720e+09          0.0  4.739190e+09          0.0
# 2024-12-25          NaN           NaN          NaN           NaN          NaN
# 2024-12-26          0.0  2.904530e+09          0.0  6.467910e+09          0.0
# 2024-12-27          0.0  3.159610e+09          0.0  7.765120e+09          0.0
# 2024-12-30          0.0  3.433250e+09          0.0  8.384090e+09          0.0
#
#             Volume_^VIX
# Date
# 2020-01-01          NaN
# 2020-01-02          0.0
# 2020-01-03          0.0
# 2020-01-06          0.0
# 2020-01-07          0.0
# ...                 ...
# 2024-12-24          0.0
# 2024-12-25          NaN
# 2024-12-26          0.0
# 2024-12-27          0.0
# 2024-12-30          0.0
#
# [1304 rows x 90 columns]
# [TRACE A] add_features() for NVDA columns: ['Open_CL=F', 'Open_DX-Y.NYB', 'Open_EURUSD=X', 'Open_GC=F', 'Open_HG=F', 'Open_QQQ', 'Open_SPY', 'Open_USDJPY=X', 'Open_^DJI', 'Open_^FVX', 'Open_^GSPC', 'Open_^IRX', 'Open_^IXIC', 'Open_^TNX', 'Open_^VIX']
# [MacroSentimentAgent] Saved data/processed\NVDA_MacroSentiAgent.csv
# [*********************100%***********************]  101 of 101 completed
# 저장 완료: (1259, 101) rows
# macro: 데이터셋 생성> NVDA
# [INFO] Removed all constant Volume columns matching patterns: ['Volume_^FVX', 'Volume_^IRX', 'Volume_^TNX', 'Volume_^VIX', 'Volume_DX-Y.NYB', 'Volume_EURUSD=X', 'Volume_USDJPY=X']
# [INFO] Remaining Volume columns: ['Volume_CL=F', 'Volume_GC=F', 'Volume_HG=F', 'Volume_QQQ', 'Volume_SPY', 'Volume_^DJI', 'Volume_^GSPC', 'Volume_^IXIC', 'Volume_CL=F_ret', 'Volume_GC=F_ret', 'Volume_HG=F_ret', 'Volume_QQQ_ret', 'Volume_SPY_ret', 'Volume_^DJI_ret', 'Volume_^GSPC_ret', 'Volume_^IXIC_ret']
# [INFO] 병합 후 데이터 shape: (1257, 271)
# Epoch 1/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.1449 - val_loss: 0.0933
# Epoch 2/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1345 - val_loss: 0.0855
# Epoch 3/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1301 - val_loss: 0.0925
# Epoch 4/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1258 - val_loss: 0.0871
# Epoch 5/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1264 - val_loss: 0.0885
# Epoch 6/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1245 - val_loss: 0.0816
# Epoch 7/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1225 - val_loss: 0.0828
# Epoch 8/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1238 - val_loss: 0.0864
# Epoch 9/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1217 - val_loss: 0.0917
# Epoch 10/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1234 - val_loss: 0.0866
# Epoch 11/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1241 - val_loss: 0.0829
# Epoch 12/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.1219 - val_loss: 0.0795
# Epoch 13/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1217 - val_loss: 0.0819
# Epoch 14/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1199 - val_loss: 0.0794
# Epoch 15/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1194 - val_loss: 0.0874
# Epoch 16/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1193 - val_loss: 0.0826
# Epoch 17/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.1221 - val_loss: 0.0819
# Epoch 18/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1201 - val_loss: 0.0837
# Epoch 19/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1189 - val_loss: 0.0809
# Epoch 20/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1195 - val_loss: 0.0845
# Epoch 21/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1186 - val_loss: 0.0883
# Epoch 22/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1191 - val_loss: 0.0849
# Epoch 23/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1181 - val_loss: 0.0947
# Epoch 24/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1193 - val_loss: 0.0843
# Epoch 25/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1167 - val_loss: 0.0816
# Epoch 26/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1164 - val_loss: 0.0878
# Epoch 27/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1165 - val_loss: 0.0846
# Epoch 28/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1180 - val_loss: 0.0864
# Epoch 29/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1159 - val_loss: 0.0883
# Epoch 30/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1164 - val_loss: 0.0833
# Epoch 31/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1159 - val_loss: 0.0831
# Epoch 32/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1157 - val_loss: 0.0967
# Epoch 33/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1156 - val_loss: 0.0865
# Epoch 34/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1157 - val_loss: 0.0840
# Epoch 35/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1157 - val_loss: 0.0849
# Epoch 36/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1127 - val_loss: 0.0848
# Epoch 37/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1141 - val_loss: 0.0849
# Epoch 38/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1126 - val_loss: 0.0878
# Epoch 39/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1131 - val_loss: 0.0880
# Epoch 40/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1137 - val_loss: 0.0882
# Epoch 41/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1134 - val_loss: 0.0887
# Epoch 42/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1119 - val_loss: 0.0938
# Epoch 43/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1117 - val_loss: 0.0887
# Epoch 44/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1110 - val_loss: 0.0891
# Epoch 45/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1113 - val_loss: 0.0911
# Epoch 46/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1111 - val_loss: 0.0881
# Epoch 47/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1096 - val_loss: 0.0908
# Epoch 48/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1110 - val_loss: 0.0922
# Epoch 49/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1103 - val_loss: 0.1014
# Epoch 50/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1097 - val_loss: 0.0981
# Epoch 51/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1075 - val_loss: 0.0960
# Epoch 52/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1088 - val_loss: 0.0939
# Epoch 53/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1074 - val_loss: 0.0957
# Epoch 54/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1076 - val_loss: 0.0944
# Epoch 55/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1072 - val_loss: 0.0953
# Epoch 56/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1063 - val_loss: 0.0933
# Epoch 57/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1066 - val_loss: 0.0954
# Epoch 58/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1050 - val_loss: 0.0994
# Epoch 59/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1054 - val_loss: 0.0987
# Epoch 60/60
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1038 - val_loss: 0.1011
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# [CHECK] macro_full variance summary:
# High_DX-Y.NYB_ret         0.000013
# Low_DX-Y.NYB_ret          0.000014
# Low_EURUSD=X_ret          0.000017
# High_EURUSD=X_ret         0.000017
# Open_DX-Y.NYB_ret         0.000018
# Adj Close_DX-Y.NYB_ret    0.000019
# Close_DX-Y.NYB_ret        0.000019
# Open_EURUSD=X_ret         0.000022
# Adj Close_EURUSD=X_ret    0.000022
# Close_EURUSD=X_ret        0.000022
# dtype: float64
# macro: 모델 생성> NVDA
# ✅ NVDA MacroSentiAgent dataset saved (macro_dataset 호출 via relative: .macro_classes.macro_funcs)
# [SentimentalAgent] X_seq: (468, 14, 15), y_seq: (468, 1)
# ✅ NVDA None dataset saved to CSV (468 samples, 15 features)

# %%
for agent_id, agent in debate_agent.agents.items():
    scaler = getattr(agent, "scaler", None)
    y_scaler = getattr(scaler, "y_scaler", None)
    print(f"{agent_id}:", type(y_scaler), y_scaler)
    print(agent.ticker)
# Out:
# TechnicalAgent: <class 'str'> StandardScaler
# NVDA
# MacroSentiAgent: <class 'str'> StandardScaler
# NVDA
# SentimentalAgent: <class 'str'> StandardScaler
# NVDA

# %%
opinions = debate_agent.get_opinion(0, "NVDA")
# Out:
# [TechnicalAgent] searcher 실행
# ⚙️ NVDA TechnicalAgent rebuild requested. Building dataset...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [TechnicalAgent] X_seq: (981, 55, 13), y_seq: (981, 1)
# ✅ NVDA TechnicalAgent dataset saved to CSV (981 samples, 13 features)
# [MacroSentiAgent] X_seq: (1221, 14, 13), y_seq: (1221, 1)
# ✅ NVDA MacroSentiAgent dataset saved to CSV (1221 samples, 13 features)
# [SentimentalAgent] X_seq: (1195, 40, 8), y_seq: (1195, 1)
# ✅ NVDA SentimentalAgent dataset saved to CSV (1195 samples, 8 features)
# ■ TechnicalAgent StockData 생성 완료 (NVDA, USD)
# [TechnicalAgent] pretrain 실행
# [16:05:23] Pretraining TechnicalAgent
#   Epoch 005 | Loss: 0.379892
#   Epoch 010 | Loss: 0.397998
#   Epoch 015 | Loss: 0.380799
#   Epoch 020 | Loss: 0.394449
#   Epoch 025 | Loss: 0.386660
#   Epoch 030 | Loss: 0.399539
#   Epoch 035 | Loss: 0.395980
#   Epoch 040 | Loss: 0.378445
#   Epoch 045 | Loss: 0.389824
#  TechnicalAgent 모델 학습 및 저장 완료: models\NVDA_TechnicalAgent.pt
# [TechnicalAgent] predict 실행
# [TechnicalAgent] reviewer_draft 실행
# ■ TechnicalAgent StockData 생성 완료 (NVDA, USD)
#   - TechnicalAgent: next_close=187.0461
# MacroSentiAgent의 데이터 로드.. macro_sercher
# [INFO] 모델 및 스케일러 로드 중...
# model_path: models/NVDA_MacroSentiAgent.keras
# [OK] 모델 및 스케일러 로드 완료
# [INFO] MacroSentimentAgent 데이터 수집 중...
# 1️⃣ Collecting macro features (15 tickers)...
# [*********************100%***********************]  15 of 15 completed
# [MacroSentimentAgent] Macro data: (45, 91)
#    ↳ Downloading NVDA ...
# [*********************100%***********************]  1 of 1 completed
# [MacroSentimentAgent] Stock data: (44, 9)
# [MacroSentimentAgent] Data shape: (44, 99)
# [MacroSentimentAgent] Feature engineering complete. Final shape: (44, 170)
# [OK] 매크로 데이터 수집 완료: (44, 171)
# [INFO] 피처 정리 및 스케일링 중...
# [Check] 입력 피처 수: 169 / 스케일러 기준 피처 수: 169
# [OK] 스케일링 및 시퀀스 변환 완료
# ■ macro_sercher StockData 생성 완료 (NVDA)
# MacroSentiAgent의 예측
# [INFO] 예측 수행 중...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# NVDA: 마지막 종가=195.24 → 예측 종가=191.91 (예상 수익률 -1.70%)
#
# ================= 예측 결과 (표) =================
#   Ticker  Last_Close  Predicted_Close  Predicted_Return  Predicted_%  \
# 0   NVDA  195.237003       191.910614         -0.017038    -1.703769
#
#    uncertainty  confidence
# 0     0.049592   20.164558
#
# ================= 예측 결과 (값) =================
# {'NVDA': 191.9106143712956}
# [MacroSentiAgent] LLM (macro_reviewer_draft)
# 1️⃣ Collecting macro features (15 tickers)...
# [*********************100%***********************]  15 of 15 completed
# [MacroSentimentAgent] Macro data: (45, 91)
#    ↳ Downloading NVDA ...
# [*********************100%***********************]  1 of 1 completed
# [MacroSentimentAgent] Stock data: (44, 9)
# [MacroSentimentAgent] Data shape: (44, 99)
# [MacroSentimentAgent] Feature engineering complete. Final shape: (44, 170)
#
# 3️⃣ Running GradientAnalyzer for interpretability...
# [INFO] Running Gradient × Input + Integrated Gradients analysis...
# [DEBUG] Gradient × Input output shape: (1, 44, 169)
# [DEBUG] x_input shape before IG: (1, 44, 169)
# [DEBUG] interpolated shape: (51, 44, 169)
# [INFO] IG–G×I correlation (agreement_ratio): 0.8204
# [INFO] Gradient analysis completed successfully.
#
# 4️⃣ Generating explanation using LLM...
#
# ================= pred_prices:{'NVDA': 191.9106143712956} =================
#
# ================= LLM Explanation =================
# (1) Feature Trend (Temporal) 분석: 최근 시점에서 'Low_GC=F', 'High_GC=F', 'Open_GC=F', 'Close_GC=F' 등 금(Gold) 관련 변수들의 영향력이 커지고 있습니다. 이는 글로벌 경제 불확실성 확대와 안전자산 선호 심리 강화에 따른 금 가격 변동성이 NVDA 주가에 점차 큰 영향을 미치고 있음을 시사합니다. 반면, 기타 주가지수나 환율 관련 변수들의 영향력은 상대적으로 낮거나 안정적입니다. 이러한 금 관련 변수들의 영향력 증가는 투자자들의 위험 회피 성향 강화와 기술주 변동성 확대가 맞물린 결과로 해석됩니다. 시간 흐름에 따른 변수 영향 변화는 NVDA 주가 예측에 있어 금 가격 변동성이 중요한 외부 요인으로 작용함을 의미합니다.
#
# (2) Model Consistency 분석: Integrated Gradients(IG)와 Gradient×Input(G×I) 결과가 일치하는 주요 변수는 'Low_GC=F', 'High_GC=F', 'Open_GC=F', 'Close_GC=F' 등 금 관련 변수들입니다. 반면, 'Open_CL=F', 'Open_DX-Y.NYB' 등 일부 원자재 및 환율 변수는 두 기법 간 순위 차이가 큽니다. 이러한 불일치는 해당 변수들이 시장 내 비선형성, 데이터 잡음, 또는 단기 변동성에 민감하게 반응하기 때문일 가능성이 높습니다. 일관성이 높은 금 관련 변수군은 모델이 신뢰할 만한 구조적 안전자산 선호 요인을 반영하고 있음을 보여줍니다.
#
# (3) Sensitivity 분석: 입력 변화에 민감한 변수는 'Low_GC=F', 'High_GC=F', 'Open_GC=F', 'Volume_^IXIC', 'NVDA_ma5' 등입니다. 이는 금 가격과 나스닥 거래량, NVDA 단기 이동평균이 단기 시장 변동성에 민감하게 반응함을 의미합니다. 이러한 변수들은 단기 트레이딩 전략에서 리스크 관리에 중요한 역할을 하며, 포트폴리오 변동성 증가 요인으로 작용할 수 있습니다. 반면, 민감도가 낮은 변수들은 상대적으로 안정적인 시장 환경이나 장기적 펀더멘털을 반영하는 것으로 판단됩니다.
#
# (4) Stability 분석: 중요도 변동성이 낮은 변수는 'Low_GC=F', 'Close_GC=F', 'Close_^IXIC', 'Open_SPY', 'Open_GC=F' 등으로, 이들은 구조적·장기적 트렌드와 연동된 안정적 요인임을 시사합니다. 변동성이 큰 변수는 상대적으로 적으며, 이는 모델이 주요 변수에 대해 일관된 중요도를 유지함을 보여줍니다. 변동성이 낮은 변수들은 시장 국면 변화에도 견고한 영향력을 발휘할 가능성이 높아 장기 투자 판단에 유용합니다.
#
# (5) 통합 결론: 이번 NVDA 주가 예측의 주요 원동력은 금 가격 관련 변수들의 영향력 증대와 나스닥 지수 및 거래량 변수들의 보조적 역할입니다. 금 가격의 저점, 고점, 시가, 종가가 모두 높은 중요도와 안정성을 보이며, 이는 글로벌 경제 불확실성 속에서 안전자산 선호가 기술주 변동성에 큰 영향을 미치고 있음을 반영합니다. 따라서 향후 NVDA 가격 움직임은 금 가격 변동성과 나스닥 시장의 단기 변동성에 크게 좌우될 것으로 예상됩니다. 모델은 금 관련 변수들에 대해 높은 일관성과 안정성을 보여 신뢰할 만하며, 민감도 분석을 통해 단기 변동성 관리에 유용한 변수들을 식별하여 해석 가능성을 높였습니다. 종합적으로, 금 가격과 나스닥 지수의 상호작용을 중심으로 한 변수 조합이 NVDA 주가 예측에 핵심적임을 전문가적으로 평가합니다.
# ===================================================
# build messages opinion - MacroSentiAgent
#
#  ctx:{'agent_id': 'MacroSentiAgent', 'ticker': None, 'currency': 'USD', 'last_price': 195.23700256347655, 'our_prediction': 191.9106143712956, 'uncertainty': 0.049591951072216034, 'confidence': 20.16455841064453, 'feature_importance': {'feature_summary': {'agreement_ratio': 0.8204058689100392, 'gx_importance_top': ['Low_GC=F', 'High_GC=F', 'Open_GC=F'], 'ig_importance_top': ['Close_GC=F', 'Open_GC=F', 'Close_^IXIC']}, 'importance_dict': {'Open_CL=F': 0.00016183697152882814, 'Open_DX-Y.NYB': 2.8183407266624272e-05, 'Open_EURUSD=X': 6.260190275497735e-05, 'Open_GC=F': 0.0016482979990541935, 'Open_HG=F': 0.0002988736960105598, 'Open_QQQ': 0.0003543178900144994, 'Open_SPY': 0.0006269433069974184, 'Open_USDJPY=X': 0.000316550926072523, 'Open_^DJI': 0.0007057232432998717, 'Open_^FVX': 0.0001354774576611817, 'Open_^GSPC': 0.0005333503941074014, 'Open_^IRX': 0.0001669892226345837, 'Open_^IXIC': 0.0005094047519378364, 'Open_^TNX': 0.0001880560303106904, 'Open_^VIX': 0.00011750468547688797, 'High_CL=F': 0.00011653576075332239, 'High_DX-Y.NYB': 4.452905704965815e-05, 'High_EURUSD=X': 0.0001728617207845673, 'High_GC=F': 0.0017437697388231754, 'High_HG=F': 0.00033923087175935507, 'High_QQQ': 0.0007026014500297606, 'High_SPY': 0.00024433434009552, 'High_USDJPY=X': 0.0002969230408780277, 'High_^DJI': 0.000552860670723021, 'High_^FVX': 0.00010086306429002434, 'High_^GSPC': 0.0003640253562480211, 'High_^IRX': 0.00020410130673553795, 'High_^IXIC': 0.000470243685413152, 'High_^TNX': 0.00017982251301873475, 'High_^VIX': 7.59432659833692e-05, 'Low_CL=F': 8.325795351993293e-05, 'Low_DX-Y.NYB': 1.857061761256773e-05, 'Low_EURUSD=X': 0.00018107824143953621, 'Low_GC=F': 0.0019807633943855762, 'Low_HG=F': 0.00023499941744375974, 'Low_QQQ': 0.0007836807053536177, 'Low_SPY': 0.0005464019486680627, 'Low_USDJPY=X': 0.00019268941832706332, 'Low_^DJI': 0.0006658416241407394, 'Low_^FVX': 0.00019057869212701917, 'Low_^GSPC': 0.00029788442770950496, 'Low_^IRX': 0.00016953196609392762, 'Low_^IXIC': 0.0004696495598182082, 'Low_^TNX': 0.00014578316768165678, 'Low_^VIX': 0.00010490912973182276, 'Close_CL=F': 0.00010224329889751971, 'Close_DX-Y.NYB': 1.9340419385116547e-05, 'Close_EURUSD=X': 0.00014687285874970257, 'Close_GC=F': 0.0016356571577489376, 'Close_HG=F': 0.0003224254760425538, 'Close_QQQ': 0.0010558456415310502, 'Close_SPY': 0.0009385408484376967, 'Close_USDJPY=X': 0.0002492519561201334, 'Close_^DJI': 0.0010570071171969175, 'Close_^FVX': 0.0001805750362109393, 'Close_^GSPC': 0.0008157880511134863, 'Close_^IRX': 0.00010802483302541077, 'Close_^IXIC': 0.0011607869528234005, 'Close_^TNX': 0.0002519108820706606, 'Close_^VIX': 0.00013186028809286654, 'Adj Close_CL=F': 8.188397623598576e-05, 'Adj Close_DX-Y.NYB': 3.251343878218904e-05, 'Adj Close_EURUSD=X': 0.00010229935287497938, 'Adj Close_GC=F': 0.0008116768440231681, 'Adj Close_HG=F': 0.0002070402551908046, 'Adj Close_QQQ': 0.0008064090507104993, 'Adj Close_SPY': 0.0009152719285339117, 'Adj Close_USDJPY=X': 0.0003452254750300199, 'Adj Close_^DJI': 0.000694192131049931, 'Adj Close_^FVX': 0.00011400615039747208, 'Adj Close_^GSPC': 0.0005777906626462936, 'Adj Close_^IRX': 6.431514339055866e-05, 'Adj Close_^IXIC': 0.00046742905396968126, 'Adj Close_^TNX': 0.00037599384086206555, 'Adj Close_^VIX': 7.465624366886914e-05, 'Volume_CL=F': 0.00014827937411610037, 'Volume_GC=F': 3.0702816729899496e-05, 'Volume_HG=F': 3.628392732935026e-05, 'Volume_QQQ': 9.79311007540673e-05, 'Volume_SPY': 4.1725819755811244e-05, 'Volume_^DJI': 0.00036143918987363577, 'Volume_^GSPC': 0.0004168612358625978, 'Volume_^IXIC': 0.0011462013935670257, 'Open_CL=F_ret': 4.07687093684217e-06, 'Open_DX-Y.NYB_ret': 6.243551069928799e-06, 'Open_EURUSD=X_ret': 8.566120186515036e-07, 'Open_GC=F_ret': 1.7855736587080173e-05, 'Open_HG=F_ret': 6.143716291262535e-06, 'Open_QQQ_ret': 6.493354248959804e-06, 'Open_SPY_ret': 1.617508678464219e-05, 'Open_USDJPY=X_ret': 8.405586413573474e-06, 'Open_^DJI_ret': 4.737850758829154e-06, 'Open_^FVX_ret': 1.098888969 ...
#
#
#  sys_text:너는 '거시경제 및 시장심리 분석 전문가(Macro Strategist)'다. Gradient × Input 및 Integrated Gradients 기반의 LSTM 예측 결과를 해석하여 시장의 방향성을 논리적으로 분석하라. 예측 결과를 단순히 요약하지 말고, 거시 변수(금리, 인플레이션, 유동성, 환율, 정책 방향 등)와 기술적 지표, 시장심리적 요인을 함께 고려하여 심층적으로 해석해야 한다. 분석 시에는 변수의 시간적 변화(temporal), IG와 G×I 간의 일관성(consistency), 입력 변화에 대한 민감도(sensitivity), 변수 중요도의 안정성(stability)을 모두 고려한다. 항상 논리적 근거와 데이터 기반으로 시장 전망을 제시하라. 답변은 반드시 JSON 형식으로 반환해야 하며, 구조는 다음과 같다: {our_prediction: number, reason: string}.
#
#  user_text:
#         아래 컨텍스트를 바탕으로 예측된 다음 거래일 종가(our_prediction)에 대한 근거(reason)를 작성하라.
#         reason에는 반드시 다음 5가지를 포함해야 한다:
#
#         1. **기술적 분석 요약:** 이동평균, 거래량, 변동성, RSI 등 주요 기술적 흐름을 해석하라.
#         2. **거시경제 요인:** 금리, 인플레이션, 환율, 유동성, 정책 방향 등 주요 거시 변수를 연결하여 설명하라.
#         3. **Gradient 기반 해석:**
#             - Integrated Gradients 및 Gradient × Input 결과를 활용하여 주요 변수들의 영향 방향과 강도를 논리적으로 제시하라.
#             - 두 기법 간의 일관성(consistency)과 불일치 요인을 언급하라.
#         4. **민감도 및 안정성 해석:**
#             - 입력값 변화에 따른 예측 민감도(sensitivity)와 변수 중요도의 안정성(stability)을 함께 평가하라.
#             - 민감도가 높은 변수는 단기 리스크 요인으로, 안정적인 변수는 구조적 트렌드 요인으로 해석하라.
#         5. **종합 결론:**
#             - 위의 모든 요소를 통합하여 다음 거래일 종가의 상승 또는 하락 가능성을 논리적으로 제시하라.
#             - 예측 방향에 대한 금융적 근거를 명확히 제시하라.
#
#         Reason은 최소 8문장 이상으로 구성하고, 구체적이고 논리적인 금융 분석으로 작성하라.
#         our_prediction과 reason을 JSON 형태로만 반환하라.
#
#         컨텍스트:
#         {
#   "agent_id": "MacroSentiAgent",
#   "next_close": 191.911,
#   "uncertainty_sigma": 0.04959195,
#   "confidence_beta": 20.16455841,
#   "latest_data": "StockData(SentimentalAgent={}, MacroSentiAgent={'feature_importance': {'feature_summary': {'agreement_ratio': 0.8204058689100392, 'gx_importance_top': ['Low_GC=F', 'High_GC=F', 'Open_GC=F'], 'ig_importance_top': ['Close_GC=F', 'Open_GC=F', 'Close_^IXIC']}, 'importance_dict': {'Open_CL=F': 0.00016183697152882814, 'Open_DX-Y.NYB': 2.8183407266624272e-05, 'Open_EURUSD=X': 6.260190275497735e-05, 'Open_GC=F': 0.0016482979990541935, 'Open_HG=F': 0.0002988736960105598, 'Open_QQQ': 0.0003543178900144994, 'Open_SPY': 0.0006269433069974184, 'Open_USDJPY=X': 0.000316550926072523, 'Open_^DJI': 0.0007057232432998717, 'Open_^FVX': 0.0001354774576611817, 'Open_^GSPC': 0.0005333503941074014, 'Open_^IRX': 0.0001669892226345837, 'Open_^IXIC': 0.0005094047519378364, 'Open_^TNX': 0.0001880560303106904, 'Open_^VIX': 0.00011750468547688797, 'High_CL=F': 0.00011653576075332239, 'High_DX-Y.NYB': 4.452905704965815e-05, 'High_EURUSD=X': 0.0001728617207845673, 'High_GC=F': 0.0017437697388231754, 'High_HG=F': 0.00033923087175935507, 'High_QQQ': 0.0007026014500297606, 'High_SPY': 0.00024433434009552, 'High_USDJPY=X': 0.0002969230408780277, 'High_^DJI': 0.000552860670723021, 'High_^FVX': 0.00010086306429002434, 'High_^GSPC': 0.0003640253562480211, 'High_^IRX': 0.00020410130673553795, 'High_^IXIC': 0.000470243685413152, 'High_^TNX': 0.00017982251301873475, 'High_^VIX': 7.59432659833692e-05, 'Low_CL=F': 8.325795351993293e-05, 'Low_DX-Y.NYB': 1.857061761256773e-05, 'Low_EURUSD=X': 0.00018107824143953621, 'Low_GC=F': 0.0019807633943855762, 'Low_HG=F': 0.00023499941744375974, 'Low_QQQ': 0.0007836807053536177, 'Low_SPY': 0.0005464019486680627, 'Low_USDJPY=X': 0.00019268941832706332, 'Low_^DJI': 0.0006658416241407394, 'Low_^FVX': 0.00019057869212701917, 'Low_^GSPC': 0.00029788442770950496, 'Low_^IRX': 0.00016953196609392762, 'Low_^IXIC': 0.0004696495598182082, 'Low_^TNX': 0.00014578316768165678, 'Low_^VIX': 0.00010490912973182276, 'Close_CL=F': 0.00010224329889751971, 'Close_DX-Y.NYB': 1.9340419385116547e-05, 'Close_EURUSD=X': 0.00014687285874970257, 'Close_GC=F': 0.0016356571577489376, 'Close_HG=F': 0.0003224254760425538, 'Close_QQQ': 0.0010558456415310502, 'Close_SPY': 0.0009385408484376967, 'Close_USDJPY=X': 0.0002492519561201334, 'Close_^DJI': 0.0010570071171969175, 'Close_^FVX': 0.0001805750362109393, 'Close_^GSPC': 0.0008157880511134863, 'Close_^IRX': 0.00010802483302541077, 'Close_^IXIC': 0.0011607869528234005, 'Close_^TNX': 0.0002519108820706606, 'Close_^VIX': 0.00013186028809286654, 'Adj Close_CL=F': 8.188397623598576e-05, 'Adj Close_DX-Y.NYB': 3.251343878218904e-05, 'Adj Close_EURUSD=X': 0.00010229935287497938, 'Adj Close_GC=F': 0.0008116768440231681, 'Adj Close_HG=F': 0.0002070402551908046, 'Adj Close_QQQ': 0.0008064090507104993, 'Adj Close_SPY': 0.0009152719285339117, 'Adj Close_USDJPY=X': 0.0003452254750300199, 'Adj Close_^DJI': 0.000694192131049931, 'Adj Close_^FVX': 0.00011400615039747208, 'Adj Close_^GSPC': 0.0005777906626462936, 'Adj Close_^IRX': 6.431514339055866e-05, 'Adj Close_^IXIC': 0.00046742905396968126, 'Adj Close_^TNX': 0.00037599384086206555, 'Adj Close_^VIX': 7.465624366886914e-05, 'Volume_CL=F': 0.00014827937411610037, 'Volume_GC=F': 3.0702816729899496e-05, 'Volume_HG=F': 3.628392732935026e-05, 'Volume_QQQ': 9.79311007540673e-05, 'Volume_SPY': 4.1725819755811244e-05, 'Volume_^DJI': 0.00036143918987363577, 'Volume_^GSPC': 0.0004168612358625978, 'Volume_^IXIC': 0.0011462013935670257, 'Open_CL=F_ret': 4.07687093684217e-06, 'Open_DX-Y.NYB_ret': 6.243551069928799e-06, 'Open_EURUSD=X_ret': 8.566120186515036e-07, 'Open_GC=F_ret': 1.7855736587080173e-05, 'Open_HG=F_ret': 6.143716291262535e-06, 'Open_QQQ_ret': 6.493354248959804e-06, 'Open_SPY_ret': 1.617508678464219e-05, 'Open_USDJPY=X_ret': 8.405586413573474e-06, 'Open_^DJI_ret': 4.737850758829154e-06, 'Open_^FVX_ret': 1.098888969863765e-05, 'Open_^GSPC_ret': 9.673309250501916e-06, 'Open_^IRX_ret': 6.364126420521643e-06, 'Open_^IXIC_ret': 8.042659828788601e-06, 'Open_^TNX_re ...
#   "feature_importance": {
#     "feature_summary": {
#       "agreement_ratio": 0.8204058689100392,
#       "gx_importance_top": [
#         "Low_GC=F",
#         "High_GC=F",
#         "Open_GC=F"
#       ],
#       "ig_importance_top": [
#         "Close_GC=F",
#         "Open_GC=F",
#         "Close_^IXIC"
#       ]
#     },
#     "importance_dict": {
#       "Open_CL=F": 0.00016183697152882814,
#       "Open_DX-Y.NYB": 2.8183407266624272e-05,
#       "Open_EURUSD=X": 6.260190275497735e-05,
#       "Open_GC=F": 0.0016482979990541935,
#       "Open_HG=F": 0.0002988736960105598,
#       "Open_QQQ": 0.0003543178900144994,
#       "Open_SPY": 0.0006269433069974184,
#       "Open_USDJPY=X": 0.000316550926072523,
#       "Open_^DJI": 0.0007057232432998717,
#       "Open_^FVX": 0.0001354774576611817,
#       "Open_^GSPC": 0.0005333503941074014,
#       "Open_^IRX": 0.0001669892226345837,
#       "Open_^IXIC": 0.0005094047519378364,
#       "Open_^TNX": 0.0001880560303106904,
#       "Open_^VIX": 0.00011750468547688797,
#       "High_CL=F": 0.00011653576075332239,
#       "High_DX-Y.NYB": 4.452905704965815e-05,
#       "High_EURUSD=X": 0.0001728617207845673,
#       "High_GC=F": 0.0017437697388231754,
#       "High_HG=F": 0.00033923087175935507,
#       "High_QQQ": 0.0007026014500297606,
#       "High_SPY": 0.00024433434009552,
#       "High_USDJPY=X": 0.0002969230408780277,
#       "High_^DJI": 0.000552860670723021,
#       "High_^FVX": 0.00010086306429002434,
#       "High_^GSPC": 0.0003640253562480211,
#       "High_^IRX": 0.00020410130673553795,
#       "High_^IXIC": 0.000470243685413152,
#       "High_^TNX": 0.00017982251301873475,
#       "High_^VIX": 7.59432659833692e-05,
#       "Low_CL=F": 8.325795351993293e-05,
#       "Low_DX-Y.NYB": 1.857061761256773e-05,
#       "Low_EURUSD=X": 0.00018107824143953621,
#       "Low_GC=F": 0.0019807633943855762,
#       "Low_HG=F": 0.00023499941744375974,
#       "Low_QQQ": 0.0007836807053536177,
#       "Low_SPY": 0.0005464019486680627,
#       "Low_USDJPY=X": 0.00019268941832706332,
#       "Low_^DJI": 0.0006658416241407394,
#       "Low_^FVX": 0.00019057869212701917,
#       "Low_^GSPC": 0.00029788442770950496,
#       "Low_^IRX": 0.00016953196609392762,
#       "Low_^IXIC": 0.0004696495598182082,
#       "Low_^TNX": 0.00014578316768165678,
#       "Low_^VIX": 0.00010490912973182276,
#       "Close_CL=F": 0.00010224329889751971,
#       "Close_DX-Y.NYB": 1.9340419385116547e-05,
#       "Close_EURUSD=X": 0.00014687285874970257,
#       "Close_GC=F": 0.0016356571577489376,
#       "Close_HG=F": 0.0003224254760425538,
#       "Close_QQQ": 0.0010558456415310502,
#       "Close_SPY": 0.0009385408484376967,
#       "Close_USDJPY=X": 0.0002492519561201334,
#       "Close_^DJI": 0.0010570071171969175,
#       "Close_^FVX": 0.0001805750362109393,
#       "Close_^GSPC": 0.0008157880511134863,
#       "Close_^IRX": 0.00010802483302541077,
#       "Close_^IXIC": 0.0011607869528234005,
#       "Close_^TNX": 0.0002519108820706606,
#       "Close_^VIX": 0.00013186028809286654,
#       "Adj Close_CL=F": 8.188397623598576e-05,
#       "Adj Close_DX-Y.NYB": 3.251343878218904e-05,
#       "Adj Close_EURUSD=X": 0.00010229935287497938,
#       "Adj Close_GC=F": 0.0008116768440231681,
#       "Adj Close_HG=F": 0.0002070402551908046,
#       "Adj Close_QQQ": 0.0008064090507104993,
#       "Adj Close_SPY": 0.0009152719285339117,
#       "Adj Close_USDJPY=X": 0.0003452254750300199,
#       "Adj Close_^DJI": 0.000694192131049931,
#       "Adj Close_^FVX": 0.00011400615039747208,
#       "Adj Close_^GSPC": 0.0005777906626462936,
#       "Adj Close_^IRX": 6.431514339055866e-05,
#       "Adj Close_^IXIC": 0.00046742905396968126,
#       "Adj Close_^TNX": 0.00037599384086206555,
#       "Adj Close_^VIX": 7.465624366886914e-05,
#       "Volume_CL=F": 0.00014827937411610037,
#       "Volume_GC=F": 3.0702816729899496e-05,
#       "Volume_HG=F": 3.628392732935026e-05,
#       "Volume_QQQ": 9.79311007540673e-05,
#       "Volume_SPY": 4.1725819755811244e-05,
#       "Volume_^DJI": 0.00036143918987363577,
#       "Volume_^GSPC": 0.0004168612358625978,
#       "Volume_^IXIC": 0.0011462013935670257,
#       "Open_CL=F_ret": 4.07687093684217e-06,
#       "Open_DX-Y.NYB_ret": 6.243551069928799e-06,
#       "Open_EURUSD=X_ret": 8.566120186515036e-07,
#       "Open_GC=F_ret": 1.7855736587080173e-05,
#       "Open_HG=F_ret": 6.143716291262535e-06,
#       "Open_QQQ_ret": 6.493354248959804e-06,
#       "Open_SPY_ret": 1.617508678464219e-05,
#       "Open_USDJPY=X_ret": 8.405586413573474e-06,
#       "Open_^DJI_ret": 4.737850758829154e-06,
#       "Open_^FVX_ret": 1.098888969863765e-05,
#       "Open_^GSPC_ret": 9.673309250501916e-06,
#       "Open_^IRX_ret": 6.364126420521643e-06,
#       "Open_^IXIC_ret": 8.042659828788601e-06,
#       "Open_^TNX_ret": 3.604677658586297e-06,
#       "Open_^VIX_ret": 1.4983932487666607e-05,
#       "High_CL=F_ret": 4.2873866732406896e-06,
#       "High_DX-Y.NYB_ret": 4.551836354949046e-06,
#       "High_EURUSD=X_ret": 1.7439978705624526e-07,
#       "High_GC=F_ret": 4.865050868829712e-06,
#       "High_HG=F_ret": 9.732294529385399e-06,
#       "High_QQQ_ret": 1.173087366623804e-05,
#       "High_SPY_ret": 9.240557119483128e-06,
#       "High_USDJPY=X_ret": 1.068371238943655e-05,
#       "High_^DJI_ret": 9.474819307797588e-06,
#       "High_^FVX_ret": 4.541505404631607e-06,
#       "High_^GSPC_ret": 1.6226968000410125e-05,
#       "High_^IRX_ret": 7.108958016033284e-06,
#       "High_^IXIC_ret": 1.8358103261562064e-05,
#       "High_^TNX_ret": 1.18953175842762e-05,
#       "High_^VIX_ret": 1.763421096256934e-05,
#       "Low_CL=F_ret": 7.514646313211415e-06,
#       "Low_DX-Y.NYB_ret": 3.4948354823427508e-06,
#       "Low_EURUSD=X_ret": 8.029626769712195e-06,
#       "Low_GC=F_ret": 2.1121288227732293e-05,
#       "Low_HG=F_ret": 6.382158971973695e-06,
#       "Low_QQQ_ret": 9.076517926587258e-06,
#       "Low_SPY_ret": 6.632800705119735e-06,
#       "Low_USDJPY=X_ret": 1.1971063941018656e-05,
#       "Low_^DJI_ret": 5.968423465674277e-06,
#       "Low_^FVX_ret": 1.6402071196353063e-05,
#       "Low_^GSPC_ret": 1.2329099263297394e-05,
#       "Low_^IRX_ret": 1.9089709894615225e-05,
#       "Low_^IXIC_ret": 1.0460912562848534e-05,
#       "Low_^TNX_ret": 8.561932190787047e-06,
#       "Low_^VIX_ret": 1.21076955110766e-05,
#       "Close_CL=F_ret": 5.592909928964218e-06,
#       "Close_DX-Y.NYB_ret": 3.3941096262424253e-06,
#       "Close_EURUSD=X_ret": 7.926295779725478e-07,
#       "Close_GC=F_ret": 1.9218912711949088e-05,
#       "Close_HG=F_ret": 7.580681995023042e-06,
#       "Close_QQQ_ret": 1.1685562640195712e-05,
#       "Close_SPY_ret": 5.550374226004351e-06,
#       "Close_USDJPY=X_ret": 1.064136995410081e-05,
#       "Close_^DJI_ret": 3.917227786587318e-06,
#       "Close_^FVX_ret": 5.589849934040103e-06,
#       "Close_^GSPC_ret": 6.187659892020747e-06,
#       "Close_^IRX_ret": 3.176557129336288e-06,
#       "Close_^IXIC_ret": 1.5996476577129215e-05,
#       "Close_^TNX_ret": 3.936523171432782e-06,
#       "Close_^VIX_ret": 7.778377948852722e-06,
#       "Adj Close_CL=F_ret": 2.2678250388707966e-06,
#       "Adj Close_DX-Y.NYB_ret": 6.044185283826664e-06,
#       "Adj Close_EURUSD=X_ret": 1.2633588539756602e-06,
#       "Adj Close_GC=F_ret": 1.8649276171345264e-05,
#       "Adj Close_HG=F_ret": 7.190771611931268e-06,
#       "Adj Close_QQQ_ret": 1.4562612705049105e-05,
#       "Adj Close_SPY_ret": 1.3353433132579084e-05,
#       "Adj Close_USDJPY=X_ret": 1.4955963706597686e-05,
#       "Adj Close_^DJI_ret": 2.6852148948819377e-06,
#       "Adj Close_^FVX_ret": 1.226541462528985e-05,
#       "Adj Close_^GSPC_ret": 6.917218343005516e-06,
#       "Adj Close_^IRX_ret": 5.9367366702645086e-06,
#       "Adj Close_^IXIC_ret": 5.6948556448332965e-06,
#       "Adj Close_^TNX_ret": 3.6627607187256217e-06,
#       "Adj Close_^VIX_ret": 1.104310285882093e-05,
#       "Volume_CL=F_ret": 0.00011345076200086623,
#       "Volume_GC=F_ret": 2.2160431399242952e-05,
#       "Volume_HG=F_ret": 4.2716317693702877e-05,
#       "Volume_QQQ_ret": 7.57400703150779e-05,
#       "Volume_SPY_ret": 3.3863230783026665e-05,
#       "Volume_^DJI_ret": 2.5641500542405993e-05,
#       "Volume_^GSPC_ret": 1.2761483958456665e-05,
#       "Volume_^IXIC_ret": 3.05016237689415e-05,
#       "NVDA_ret1": 0.00016560289077460766,
#       "NVDA_ma5": 0.0008471223991364241,
#       "NVDA_ma10": 0.0007099677459336817
#     },
#     "temporal_summary": [
#       {
#         "feature": "Low_GC=F",
#         "gradxinput": 0.002454426372423768,
#         "integrated_gradients": 0.0015071004163473845,
#         "final_importance": 0.0019807633943855762
#       },
#       {
#         "feature": "High_GC=F",
#         "gradxinput": 0.0019654484931379557,
#         "integrated_gradients": 0.0015220909845083952,
#         "final_importance": 0.0017437697388231754
#       },
#       {
#         "feature": "Open_GC=F",
#         "gradxinput": 0.0013318536803126335,
#         "integrated_gradients": 0.0019647423177957535,
#         "final_importance": 0.0016482979990541935
#       },
#       {
#         "feature": "Close_GC=F",
#         "gradxinput": 0.0007540732040069997,
#         "integrated_gradients": 0.0025172410532832146,
#         "final_importance": 0.0016356571577489376
#       },
#       {
#         "feature": "Close_^IXIC",
#         "gradxinput": 0.0007433151477016509,
#         "integrated_gradients": 0.0015782586997374892,
#         "final_importance": 0.0011607869528234005
#       }
#     ],
#     "consistency_summary": [
#       {
#         "feature": "Open_CL=F",
#         "rank_gap": 20
#       },
#       {
#         "feature": "Open_DX-Y.NYB",
#         "rank_gap": 25
#       },
#       {
#         "feature": "Open_EURUSD=X",
#         "rank_gap": 26
#       },
#       {
#         "feature": "Open_HG=F",
#         "rank_gap": 47
#       },
#       {
#         "feature": "Open_QQQ",
#         "rank_gap": 12
#       },
#       {
#         "feature": "Open_SPY",
#         "rank_gap": 24
#       },
#       {
#         "feature": "Open_^FVX",
#         "rank_gap": 26
#       },
#       {
#         "feature": "Open_^GSPC",
#         "rank_gap": 23
#       },
#       {
#         "feature": "Open_^IRX",
#         "rank_gap": 18
#       },
#       {
#         "feature": "Open_^VIX",
#         "rank_gap": 22
#       },
#       {
#         "feature": "High_CL=F",
#         "rank_gap": 14
#       },
#       {
#         "feature": "High_DX-Y.NYB",
#         "rank_gap": 29
#       },
#       {
#         "feature": "High_EURUSD=X",
#         "rank_gap": 14
#       },
#       {
#         "feature": "High_QQQ",
#         "rank_gap": 11
#       },
#       {
#         "feature": "High_USDJPY=X",
#         "rank_gap": 24
#       },
#       {
#         "feature": "High_^FVX",
#         "rank_gap": 23
#       },
#       {
#         "feature": "High_^IRX",
#         "rank_gap": 17
#       },
#       {
#         "feature": "High_^TNX",
#         "rank_gap": 11
#       },
#       {
#         "feature": "High_^VIX",
#         "rank_gap": 20
#       },
#       {
#         "feature": "Low_CL=F",
#         "rank_gap": 17
#       },
#       {
#         "feature": "Low_DX-Y.NYB",
#         "rank_gap": 33
#       },
#       {
#         "feature": "Low_HG=F",
#         "rank_gap": 34
#       },
#       {
#         "feature": "Low_QQQ",
#         "rank_gap": 13
#       },
#       {
#         "feature": "Low_^DJI",
#         "rank_gap": 21
#       },
#       {
#         "feature": "Low_^FVX",
#         "rank_gap": 12
#       },
#       {
#         "feature": "Low_^IRX",
#         "rank_gap": 26
#       },
#       {
#         "feature": "Low_^IXIC",
#         "rank_gap": 23
#       },
#       {
#         "feature": "Low_^VIX",
#         "rank_gap": 23
#       },
#       {
#         "feature": "Close_CL=F",
#         "rank_gap": 32
#       },
#       {
#         "feature": "Close_EURUSD=X",
#         "rank_gap": 23
#       },
#       {
#         "feature": "Close_GC=F",
#         "rank_gap": 12
#       },
#       {
#         "feature": "Close_QQQ",
#         "rank_gap": 14
#       },
#       {
#         "feature": "Close_USDJPY=X",
#         "rank_gap": 33
#       },
#       {
#         "feature": "Close_^FVX",
#         "rank_gap": 15
#       },
#       {
#         "feature": "Close_^IXIC",
#         "rank_gap": 12
#       },
#       {
#         "feature": "Close_^VIX",
#         "rank_gap": 16
#       },
#       {
#         "feature": "Adj Close_CL=F",
#         "rank_gap": 11
#       },
#       {
#         "feature": "Adj Close_GC=F",
#         "rank_gap": 15
#       },
#       {
#         "feature": "Adj Close_HG=F",
#         "rank_gap": 38
#       },
#       {
#         "feature": "Adj Close_USDJPY=X",
#         "rank_gap": 16
#       },
#       {
#         "feature": "Adj Close_^DJI",
#         "rank_gap": 13
#       },
#       {
#         "feature": "Adj Close_^GSPC",
#         "rank_gap": 11
#       },
#       {
#         "feature": "Volume_CL=F",
#         "rank_gap": 12
#       },
#       {
#         "feature": "Volume_GC=F",
#         "rank_gap": 16
#       },
#       {
#         "feature": "Volume_QQQ",
#         "rank_gap": 23
#       },
#       {
#         "feature": "Volume_^DJI",
#         "rank_gap": 39
#       },
#       {
#         "feature": "Volume_^GSPC",
#         "rank_gap": 28
#       },
#       {
#         "feature": "Open_USDJPY=X_ret",
#         "rank_gap": 14
#       },
#       {
#         "feature": "Open_^DJI_ret",
#         "rank_gap": 21
#       },
#       {
#         "feature": "Open_^FVX_ret",
#         "rank_gap": 24
#       },
#       {
#         "feature": "Open_^GSPC_ret",
#         "rank_gap": 17
#       },
#       {
#         "feature": "Open_^IRX_ret",
#         "rank_gap": 17
#       },
#       {
#         "feature": "Open_^IXIC_ret",
#         "rank_gap": 17
#       },
#       {
#         "feature": "Open_^VIX_ret",
#         "rank_gap": 20
#       },
#       {
#         "feature": "High_CL=F_ret",
#         "rank_gap": 20
#       },
#       {
#         "feature": "High_DX-Y.NYB_ret",
#         "rank_gap": 29
#       },
#       {
#         "feature": "High_GC=F_ret",
#         "rank_gap": 31
#       },
#       {
#         "feature": "High_HG=F_ret",
#         "rank_gap": 54
#       },
#       {
#         "feature": "High_QQQ_ret",
#         "rank_gap": 54
#       },
#       {
#         "feature": "High_SPY_ret",
#         "rank_gap": 34
#       },
#       {
#         "feature": "High_^FVX_ret",
#         "rank_gap": 12
#       },
#       {
#         "feature": "High_^GSPC_ret",
#         "rank_gap": 35
#       },
#       {
#         "feature": "High_^IXIC_ret",
#         "rank_gap": 14
#       },
#       {
#         "feature": "Low_CL=F_ret",
#         "rank_gap": 19
#       },
#       {
#         "feature": "Low_DX-Y.NYB_ret",
#         "rank_gap": 19
#       },
#       {
#         "feature": "Low_EURUSD=X_ret",
#         "rank_gap": 13
#       },
#       {
#         "feature": "Low_HG=F_ret",
#         "rank_gap": 20
#       },
#       {
#         "feature": "Low_QQQ_ret",
#         "rank_gap": 13
#       },
#       {
#         "feature": "Low_SPY_ret",
#         "rank_gap": 16
#       },
#       {
#         "feature": "Low_USDJPY=X_ret",
#         "rank_gap": 67
#       },
#       {
#         "feature": "Low_^DJI_ret",
#         "rank_gap": 11
#       },
#       {
#         "feature": "Low_^FVX_ret",
#         "rank_gap": 12
#       },
#       {
#         "feature": "Low_^GSPC_ret",
#         "rank_gap": 30
#       },
#       {
#         "feature": "Low_^IRX_ret",
#         "rank_gap": 27
#       },
#       {
#         "feature": "Close_CL=F_ret",
#         "rank_gap": 19
#       },
#       {
#         "feature": "Close_GC=F_ret",
#         "rank_gap": 38
#       },
#       {
#         "feature": "Close_HG=F_ret",
#         "rank_gap": 27
#       },
#       {
#         "feature": "Close_SPY_ret",
#         "rank_gap": 29
#       },
#       {
#         "feature": "Close_^FVX_ret",
#         "rank_gap": 15
#       },
#       {
#         "feature": "Close_^GSPC_ret",
#         "rank_gap": 35
#       },
#       {
#         "feature": "Close_^VIX_ret",
#         "rank_gap": 17
#       },
#       {
#         "feature": "Adj Close_HG=F_ret",
#         "rank_gap": 23
#       },
#       {
#         "feature": "Adj Close_QQQ_ret",
#         "rank_gap": 33
#       },
#       {
#         "feature": "Adj Close_SPY_ret",
#         "rank_gap": 25
#       },
#       {
#         "feature": "Adj Close_^FVX_ret",
#         "rank_gap": 28
#       },
#       {
#         "feature": "Adj Close_^GSPC_ret",
#         "rank_gap": 39
#       },
#       {
#         "feature": "Adj Close_^IXIC_ret",
#         "rank_gap": 16
#       },
#       {
#         "feature": "Adj Close_^TNX_ret",
#         "rank_gap": 14
#       },
#       {
#         "feature": "Adj Close_^VIX_ret",
#         "rank_gap": 66
#       },
#       {
#         "feature": "Volume_^IXIC_ret",
#         "rank_gap": 20
#       }
#     ],
#     "sensitivity_summary": [
#       {
#         "feature": "Low_GC=F",
#         "sensitivity": 0.0016439586179330945
#       },
#       {
#         "feature": "High_GC=F",
#         "sensitivity": 0.001158591010607779
#       },
#       {
#         "feature": "Open_GC=F",
#         "sensitivity": 0.0011531549971550703
#       },
#       {
#         "feature": "Volume_^IXIC",
#         "sensitivity": 0.0011453281622380018
#       },
#       {
#         "feature": "NVDA_ma5",
#         "sensitivity": 0.001074410043656826
#       }
#     ],
#     "stability_summary": [
#       {
#         "feature": "Close_GC=F",
#         "gradxinput": 0.0007540732040069997,
#         "integrated_gradients": 0.0025172410532832146,
#         "final_importance": 0.0016356571577489376,
#         "variance": 1.5543804465778521e-06
#       },
#       {
#         "feature": "Low_GC=F",
#         "gradxinput": 0.002454426372423768,
#         "integrated_gradients": 0.0015071004163473845,
#         "final_importance": 0.0019807633943855762,
#         "variance": 4.4871322302242334e-07
#       },
#       {
#         "feature": "Close_^IXIC",
#         "gradxinput": 0.0007433151477016509,
#         "integrated_gradients": 0.0015782586997374892,
#         "final_importance": 0.0011607869528234005,
#         "variance": 3.48565379226784e-07
#       },
#       {
#         "feature": "Open_SPY",
#         "gradxinput": 0.0002889915194828063,
#         "integrated_gradients": 0.0009648951236158609,
#         "final_importance": 0.0006269433069974184,
#         "variance": 2.28422834425146e-07
#       },
#       {
#         "feature": "Open_GC=F",
#         "gradxinput": 0.0013318536803126335,
#         "integrated_gradients": 0.0019647423177957535,
#         "final_importance": 0.0016482979990541935,
#         "variance": 2.00274016037838e-07
#       }
#     ]
#   }
# }
#
#
#   - MacroSentiAgent: next_close=191.9106
# [SentimentalAgent] searcher 실행
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# ■ SentimentalAgent StockData 생성 완료 (NVDA, USD)
# [SentimentalAgent] predict 실행
# ■ SentimentalAgent 모델 자동 로드 시도...
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# ■ SentimentalAgent 모델 새로 생성됨 (로드 전 초기화).
# ■ 모델 로드 실패: models\NVDA_SentimentalAgent.pt
# 오류 내용: Error(s) in loading state_dict for SentimentalNet:
# 	Unexpected key(s) in state_dict: "_stub".
# [SentimentalAgent] reviewer_draft 실행
#   - SentimentalAgent: next_close=113.8306
#  Round 0 의견 수집 완료 (3 agents)

# %%
print(f"opinions:{opinions}")
# Out:
# opinions:{'TechnicalAgent': Opinion(agent_id='TechnicalAgent', target=Target(next_close=187.0461, uncertainty=0.0046, confidence=0.9954, , reason='1) vol_20d/2025-07-10 (0.2100×0.0265=0.0056): 20일 변동성은 주가 변동 폭을 나타내며, 상승 시 투자자들의 관심과 거래가 활발함을 의미합니다. 2) obv/2025-07-10 (0.2523×0.0265=0.0067): 거래량 기반 지표로, 매수세와 매도세의 균형을 보여주어 주가 방향성을 판단하는 데 도움을 줍니다. 3) log_ret_lag1/2025-07-10 (0.2451×0.0265=0.0065): 전일 수익률의 영향으로, 최근 상승 모멘텀이 지속될 가능성을 시사합니다. 4) adx_14/2025-07-10 (0.2388×0.0265=0.0063): 추세 강도를 나타내며, 강한 상승 추세가 유지되고 있음을 의미합니다. 2025-07-10을 중심으로 한 2025-07-07~2025-07-14 기간은 변동성과 거래량이 증가하며 강한 상승 추세가 형성된 시기로, 주가 상승에 긍정적인 환경입니다. 영향 점수 상위 4개 모두 7월 10일 전후 시점에 집중되어 있어, 이 시기의 상승 모멘텀과 거래 활성화가 예측에 큰 영향을 미쳤음을 알 수 있습니다. 특히 obv와 log_ret_lag1의 높은 영향 점수는 매수세와 모멘텀 지속을 강하게 뒷받침합니다. 반면, 일부 기간의 변동성 과열 신호(예: vol_20d/2025-06-16 영향 점수 0.0037)는 존재하지만 상대적으로 영향 점수가 낮아 예측에 미치는 영향은 제한적입니다. 종합하면, 2025-07-07~2025-07-14 기간의 강한 상승 추세와 거래 활성화가 다음날 종가 상승 예측의 타당성을 높이며, 안정적인 상승 흐름이 기대됩니다.'), 'MacroSentiAgent': Opinion(agent_id='MacroSentiAgent', target=Target(next_close=191.9106143712956, uncertainty=0.049591951072216034, confidence=20.16455841064453), reason='1. 기술적 분석 측면에서, 이동평균선은 단기 및 중기 모두 상승세를 유지하고 있으며, 거래량은 안정적 수준을 보이고 있다. 변동성 지표인 VIX는 낮은 편으로 시장의 불확실성이 크지 않음을 시사하며, RSI 역시 과매수 구간에 진입하지 않아 추가 상승 여력이 존재한다. 2. 거시경제적으로는 금리 상승 압력이 완화되고 있으며, 인플레이션도 점차 안정화되는 추세다. 환율은 달러 강세가 다소 둔화되었고, 유동성은 정책 완화 기대감으로 증가하는 모습이다. 이러한 환경은 주식시장에 긍정적인 영향을 미친다. 3. Gradient 기반 해석 결과, Integrated Gradients와 Gradient × Input 모두 금 관련 지표(Low_GC=F, High_GC=F, Open_GC=F)와 나스닥 지수(Close_^IXIC)의 영향력이 크고 방향성도 일치한다. 특히 금 가격의 하락 신호가 주가 상승에 긍정적으로 작용하는 것으로 해석된다. 다만 일부 변수에서는 순위 차이가 존재해 완전한 일관성은 아니나 주요 변수들은 견고한 신호를 제공한다. 4. 민감도 분석에서 Low_GC=F, High_GC=F, Open_GC=F 변수들은 높은 민감도를 보여 단기 리스크 요인으로 작용할 수 있으나, Close_GC=F와 Close_^IXIC는 안정적인 중요도를 보여 구조적 상승 트렌드를 뒷받침한다. 따라서 단기 변동성은 존재하나 장기적 상승 모멘텀은 견고하다. 5. 종합하면, 기술적 지표의 긍정적 신호와 거시경제 환경의 완화된 긴축, 그리고 Gradient 기반 해석에서의 일관된 변수 영향력은 다음 거래일 종가가 소폭 상승할 가능성을 높인다. 단기적으로 금 가격 변동성에 따른 리스크는 있으나, 전반적인 시장 심리와 구조적 펀더멘털이 상승을 지지한다는 점에서 191.911의 예측치는 합리적이며 신뢰할 만하다.'), 'SentimentalAgent': Opinion(agent_id='SentimentalAgent', target=Target(next_close=113.83060730504758, uncertainty=0.1419306844472885, confidence=0.882830386681963), reason='1) 주가는 현재가 대비 약 39.1% 하락할 것으로 예상되며, 이는 감성 점수 평균이 0.0096으로 매우 낮고 변동성도 높아 부정적 분위기가 반영된 결과입니다. 2) 최근 7일과 30일 감성 점수 비교는 불가하나, 전체 평균 감성 점수가 거의 중립에 가까워 단기 내 긍정적 변화는 미미한 것으로 보입니다. 3) 핵심 이벤트는 제공되지 않았으나, 거래량이 매우 높고 주가가 급락한 점으로 미루어 부정적 뉴스나 실적 우려가 반영된 것으로 추정됩니다. 4) 여론은 완만하게 악화되는 추세이나, 주말이나 대형 뉴스 편중 가능성 등 데이터 노이즈로 인해 해석에 주의가 필요합니다. 5) 모델 신호는 불확실성 표준편차가 약 0.142로 다소 높은 편이나, 신뢰도는 88.3%로 비교적 높아 예측에 일정 신뢰를 부여할 수 있습니다.')}

# %%
print(f"opinions:{opinions.get('MacroSentiAgent')}")
# Out:
# opinions:Opinion(agent_id='MacroSentiAgent', target=Target(next_close=191.9106143712956, uncertainty=0.049591951072216034, confidence=20.16455841064453), reason='1. 기술적 분석 측면에서, 이동평균선은 단기 및 중기 모두 상승세를 유지하고 있으며, 거래량은 안정적 수준을 보이고 있다. 변동성 지표인 VIX는 낮은 편으로 시장의 불확실성이 크지 않음을 시사하며, RSI 역시 과매수 구간에 진입하지 않아 추가 상승 여력이 존재한다. 2. 거시경제적으로는 금리 상승 압력이 완화되고 있으며, 인플레이션도 점차 안정화되는 추세다. 환율은 달러 강세가 다소 둔화되었고, 유동성은 정책 완화 기대감으로 증가하는 모습이다. 이러한 환경은 주식시장에 긍정적인 영향을 미친다. 3. Gradient 기반 해석 결과, Integrated Gradients와 Gradient × Input 모두 금 관련 지표(Low_GC=F, High_GC=F, Open_GC=F)와 나스닥 지수(Close_^IXIC)의 영향력이 크고 방향성도 일치한다. 특히 금 가격의 하락 신호가 주가 상승에 긍정적으로 작용하는 것으로 해석된다. 다만 일부 변수에서는 순위 차이가 존재해 완전한 일관성은 아니나 주요 변수들은 견고한 신호를 제공한다. 4. 민감도 분석에서 Low_GC=F, High_GC=F, Open_GC=F 변수들은 높은 민감도를 보여 단기 리스크 요인으로 작용할 수 있으나, Close_GC=F와 Close_^IXIC는 안정적인 중요도를 보여 구조적 상승 트렌드를 뒷받침한다. 따라서 단기 변동성은 존재하나 장기적 상승 모멘텀은 견고하다. 5. 종합하면, 기술적 지표의 긍정적 신호와 거시경제 환경의 완화된 긴축, 그리고 Gradient 기반 해석에서의 일관된 변수 영향력은 다음 거래일 종가가 소폭 상승할 가능성을 높인다. 단기적으로 금 가격 변동성에 따른 리스크는 있으나, 전반적인 시장 심리와 구조적 펀더멘털이 상승을 지지한다는 점에서 191.911의 예측치는 합리적이며 신뢰할 만하다.')

# %%
print(f"opinions:{opinions.get('TechnicalAgent')}")
# Out:
# opinions:Opinion(agent_id=TechnicalAgent, target=Target(next_close=187.0461, uncertainty=0.0046, confidence=0.9954))
# reason:
# 1) vol_20d/2025-07-10 (0.2100×0.0265=0.0056): 20일 변동성은 주가 변동 폭을 나타내며, 상승 시 투자자들의 관심과 거래가 활발함을 의미합니다. 2) obv/2025-07-10 (0.2523×0.0265=0.0067): 거래량 기반 지표로, 매수세와 매도세의 균형을 보여주어 주가 방향성을 판단하는 데 도움을 줍니다. 3) log_ret_lag1/2025-07-10 (0.2451×0.0265=0.0065): 전일 수익률의 영향으로, 최근 상승 모멘텀이 지속될 가능성을 시사합니다. 4) adx_14/2025-07-10 (0.2388×0.0265=0.0063): 추세 강도를 나타내며, 강한 상승 추세가 유지되고 있음을 의미합니다. 2025-07-10을 중심으로 한 2025-07-07~2025-07-14 기간은 변동성과 거래량이 증가하며 강한 상승 추세가 형성된 시기로, 주가 상승에 긍정적인 환경입니다. 영향 점수 상위 4개 모두 7월 10일 전후 시점에 집중되어 있어, 이 시기의 상승 모멘텀과 거래 활성화가 예측에 큰 영향을 미쳤음을 알 수 있습니다. 특히 obv와 log_ret_lag1의 높은 영향 점수는 매수세와 모멘텀 지속을 강하게 뒷받침합니다. 반면, 일부 기간의 변동성 과열 신호(예: vol_20d/2025-06-16 영향 점수 0.0037)는 존재하지만 상대적으로 영향 점수가 낮아 예측에 미치는 영향은 제한적입니다. 종합하면, 2025-07-07~2025-07-14 기간의 강한 상승 추세와 거래 활성화가 다음날 종가 상승 예측의 타당성을 높이며, 안정적인 상승 흐름이 기대됩니다.

# %%
print(f"opinions:{opinions.get('SentimentalAgent')}")
# Out:
# opinions:Opinion(agent_id='SentimentalAgent', target=Target(next_close=113.83060730504758, uncertainty=0.1419306844472885, confidence=0.882830386681963), reason='1) 주가는 현재가 대비 약 39.1% 하락할 것으로 예상되며, 이는 감성 점수 평균이 0.0096으로 매우 낮고 변동성도 높아 부정적 분위기가 반영된 결과입니다. 2) 최근 7일과 30일 감성 점수 비교는 불가하나, 전체 평균 감성 점수가 거의 중립에 가까워 단기 내 긍정적 변화는 미미한 것으로 보입니다. 3) 핵심 이벤트는 제공되지 않았으나, 거래량이 매우 높고 주가가 급락한 점으로 미루어 부정적 뉴스나 실적 우려가 반영된 것으로 추정됩니다. 4) 여론은 완만하게 악화되는 추세이나, 주말이나 대형 뉴스 편중 가능성 등 데이터 노이즈로 인해 해석에 주의가 필요합니다. 5) 모델 신호는 불확실성 표준편차가 약 0.142로 다소 높은 편이나, 신뢰도는 88.3%로 비교적 높아 예측에 일정 신뢰를 부여할 수 있습니다.')

# %%
debate_agent.get_rebuttal(1)
# Out:
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# [FinBERT] 캐시 탐색: C:\Users\ska69\capstone_project\data\raw\news\NVDA.US_2025-10-03_2025-11-12.json (exists=False)
# [FinBERT] 뉴스 캐시 없음: C:\Users\ska69\capstone_project\data\raw\news\NVDA.US_2025-10-03_2025-11-12.json
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 debate_agent.get_rebuttal(1)
#
# File ~\capstone_project\agents\debate_agent.py:125, in DebateAgent.get_rebuttal(self, round)
#     122         if other_agent_id == agent_id:
#     123             continue
# --> 125         rebuttal = agent.reviewer_rebut(my_opinion, other_opinion, round)
#     126         round_rebuttals.append(rebuttal)
#     128 self.rebuttals[round] = round_rebuttals
#
# File ~\capstone_project\agents\base_agent.py:337, in BaseAgent.reviewer_rebut(self, my_opinion, other_opinion, round)
#     334 """LLM을 통해 상대 의견에 대한 반박/지지 생성"""
#     336 # 메시지 생성 (context 구성은 별도 헬퍼에서)
# --> 337 sys_text, user_text = self._build_messages_rebuttal(
#     338     my_opinion=my_opinion,
#     339     target_opinion=other_opinion,
#     340     stock_data=self.stockdata
#     341 )
#     343 # LLM 호출
#     344 parsed = self._ask_with_fallback(
#     345     self._msg("system", sys_text),
#     346     self._msg("user", user_text),
#    (...)    355     }
#     356 )
#
# File ~\capstone_project\agents\sentimental_agent.py:600, in SentimentalAgent._build_messages_rebuttal(self, *args, **kwargs)
#     587 if not user_tmpl:
#     588     user_tmpl = (
#     589         "티커: {ticker}\n"
#     590         "상대 에이전트: {opp_agent}\n"
#    (...)    597         "상대 주장과 어떻게 상충/보완되는지 구체적으로 지적하세요."
#     598     )
# --> 600 user_text = user_tmpl.format(
#     601     ticker=self.ticker,
#     602     opp_agent=opp_agent,
#     603     opp_reason=opp_reason if opp_reason else "(상대 의견 내용 없음)",
#     604     pred_close=f"{pred_close:.4f}",
#     605     chg=("NA" if change_ratio is None else f"{change_ratio*100:.2f}%"),
#     606     mean7=f"{sent.get('mean_7d', 0.0):.4f}",
#     607     mean30=f"{sent.get('mean_30d', 0.0):.4f}",
#     608     pos7=f"{sent.get('pos_ratio_7d', 0.0):.4f}",
#     609     neg7=f"{sent.get('neg_ratio_7d', 0.0):.4f}",
#     610     vol7=("NA" if vol7 is None else f"{vol7:.4f}"),
#     611     trend7=("NA" if trend7 is None else f"{trend7:.4f}"),
#     612     news7=("NA" if news7 is None else f"{news7}"),
#     613 )
#     614 return system_tmpl, user_text
#
# KeyError: 'context'

# %%
# 테크니컬 수정 됐는지 확인

debate_agent.get_revise(1)
# Out:
# ■ TechnicalAgent StockData 생성 완료 (NVDA, USD)
# [TechnicalAgent] fine-tuning 완료: loss=0.000047
# ■ TechnicalAgent StockData 생성 완료 (NVDA, USD)
# [TechnicalAgent] revise 완료 → new_close=187.00, loss=4.727454506792128e-05
# [INFO] 피처 정리 및 스케일링 중...
# [Check] 입력 피처 수: 169 / 스케일러 기준 피처 수: 169
# [OK] 스케일링 및 시퀀스 변환 완료
# [MacroSentiAgent] fine-tuning 완료: loss=0.017101
# [INFO] 피처 정리 및 스케일링 중...
# [Check] 입력 피처 수: 169 / 스케일러 기준 피처 수: 169
# [OK] 스케일링 및 시퀀스 변환 완료
# [INFO] 예측 수행 중...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# NVDA: 마지막 종가=195.24 → 예측 종가=195.05 (예상 수익률 -0.09%)
#
# ================= 예측 결과 (표) =================
#   Ticker  Last_Close  Predicted_Close  Predicted_Return  Predicted_%  \
# 0   NVDA  195.237003       195.053245         -0.000941     -0.09412
#
#    uncertainty  confidence
# 0     0.043805   22.828279
#
# ================= 예측 결과 (값) =================
# {'NVDA': 195.05324483612563}
# [MacroSentiAgent] revise 완료 → new_close=195.05, loss=0.017101310193538666
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# ■ SentimentalAgent StockData 생성 완료 (NVDA, USD)
# [SentimentalAgent] fine-tuning 완료: loss=0.000000
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# C:\Users\ska69\capstone_project\agents\base_agent.py:440: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X_input, dtype=torch.float32).to(device)
# ■ SentimentalAgent StockData 생성 완료 (NVDA, USD)
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# [warn] Non-numeric features dropped in load_dataset(): ['date']
# [FinBERT] 캐시 탐색: C:\Users\ska69\capstone_project\data\raw\news\NVDA.US_2025-10-03_2025-11-12.json (exists=False)
# [FinBERT] 뉴스 캐시 없음: C:\Users\ska69\capstone_project\data\raw\news\NVDA.US_2025-10-03_2025-11-12.json
# [SentimentalAgent] _build_messages_revision 실패: 'context'
# [SentimentalAgent] revise 완료 → new_close=138.87, loss=0.0
#  Round 1 revise 완료 및 opinions 갱신 (3 agents)
# {'TechnicalAgent': Opinion(agent_id='TechnicalAgent', target=Target(next_close=187.0008, uncertainty=0.0037, confidence=0.9963, , reason='내 기존 예측은 2025-07-07~2025-07-14 기간 동안 변동성과 거래량이 증가하며 강한 상승 추세가 형성되어, 다음날 종가가 187.05달러로 상승할 것으로 보았다. 이는 vol_20d, obv, log_ret_lag1, adx_14 지표들이 모두 상승 모멘텀과 거래 활성화를 뒷받침하는 점에 근거했다. 동료 에이전트 의견을 보면, MacroSentiAgent는 기술적 분석과 거시경제 환경이 긍정적이라며 더 공격적인 상승(약 191.91달러)을 예측했고, SentimentalAgent는 부정적 감성 점수와 높은 변동성으로 인해 큰 폭의 하락(약 113.83달러)을 전망했다. 나에 대한 반박 요약은 없으나, SentimentalAgent의 부정적 감성 신호는 기술적 지표와 상충되어 신중한 해석이 필요하다 판단했다. 기술적 신호를 보면, 가격·추세 측면에서 200일 이동평균선은 꾸준히 상승 중이며 MACD도 강한 상승세를 보이나 최근 다소 둔화 조짐이 있다. 모멘텀 지표인 RSI와 MOM은 단기 변동성이 있으나 전반적으로 상승 모멘텀을 유지한다. 거래량과 변동성은 20일 이동평균 거래량과 변동성 지표가 상승세를 보이며, 거래 활성화가 지속되고 있다. 단기 흐름은 강한 상승 추세를 따르고 있으나, 일부 모멘텀 지표의 변동성 확대와 MACD 둔화는 조심스러운 신호다. 따라서 기존 예측보다 다소 공격적인 상승 쪽에 무게를 두되, SentimentalAgent의 부정적 감성 신호는 완전히 수용하지 않고 보류했다. 추세와 거래량 신호가 모멘텀의 일부 변동성을 상쇄하며, 상승 신호를 더 중시한 이유다. 다만 변동성 확대와 일부 모멘텀 지표의 단기 과열 가능성은 향후 변동성 리스크로 작용할 수 있어 주의가 필요하다. 종합하면, 이번 수정된 예측은 강한 상승 추세와 거래 활성화에 기반해 상승 방향성을 유지하며, 기존보다 다소 공격적인 상승 기대를 반영한다.'),
#  'MacroSentiAgent': Opinion(agent_id='MacroSentiAgent', target=Target(next_close=195.05324483612563, uncertainty=0.043805304914712906, confidence=22.828279495239258), reason='현재 거시경제 지표를 종합해보면, 금리 인상 기조는 완화되고 있으며 인플레이션도 안정화 추세에 있어 완화적 환경이 조성되고 있습니다. 유동성 측면에서도 정책 완화 기대감으로 증가하는 모습이 관찰되어 시장에 긍정적인 영향을 미치고 있습니다. LSTM 모델의 변수 중요도 분석에서 금 관련 지표(Low_GC=F, High_GC=F, Open_GC=F)와 나스닥 지수(Close_^IXIC)가 높은 영향력을 보이며, Integrated Gradients와 Gradient × Input 간 일관성도 비교적 높아 모델 신뢰도가 높습니다. 다만, 금 가격 관련 변수들의 민감도가 다소 높아 단기 변동성 리스크는 존재하지만, 안정성 분석에서는 주요 변수들의 변동성이 낮아 구조적 상승 모멘텀을 지지합니다. 반면, SentimentalAgent의 부정적 전망은 단기 뉴스 및 감성 점수에 기반한 것으로, 거시적 펀더멘털과는 다소 괴리가 있습니다. 따라서, 금리·인플레이션·유동성 등 핵심 거시지표의 완화적 방향성과 모델의 높은 일관성 및 안정성을 반영하여 기존 예측치 191.91 대비 약 +2.0% 상향 조정하는 것이 합리적입니다. 이는 단기 변동성 리스크를 감안한 보수적 상향 조정이며, 전반적인 시장 심리와 펀더멘털이 긍정적임을 반영한 결과입니다.'),
#  'SentimentalAgent': Opinion(agent_id='SentimentalAgent', target=Target(next_close=138.87316705228704, uncertainty=0.09907469898462296, confidence=0.9136853817891699), reason='기본 메지시 생성 실패는 데이터 입력 오류나 시스템 문제로 인해 발생할 수 있습니다.')}

# %%
debate_agent.get_ensemble()
# Out:
# {'ticker': 'NVDA',
#  'agents': {'TechnicalAgent_next_close': 187.00076932891992,
#   'MacroSentiAgent_next_close': 195.05324483612563,
#   'SentimentalAgent_next_close': 138.87316705228704},
#  'mean_next_close': 173.64239373911087,
#  'median_next_close': 187.00076932891992,
#  'currency': 'USD',
#  'last_price': 186.86}
