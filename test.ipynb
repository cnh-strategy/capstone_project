# %%
import warnings
from agents.debate_agent import DebateAgent

warnings.filterwarnings('ignore')

# %%
agent = DebateAgent('TSLA')
agent.run()
# Out:
# [07:22:33] 데이터셋 생성은 각 Agent에서 처리하므로 DebateAgent.run에서는 스킵합니다.
# [INFO] Ensemble Model 로드 완료: models/TSLA_ensemble_lightgbm.pkl
#
# ...
# [07:22:33] Round 0: 초기 Opinion 수집 시작
# ...
# [07:22:33] [TechnicalAgent] searcher 실행 (데이터셋 준비)
# [07:22:33] [TechnicalAgent] 기존 모델 사용: models/TSLA_TechnicalAgent.pt
# [07:22:33] [TechnicalAgent] predict 실행
# [07:22:33] [TechnicalAgent] reviewer_draft 실행
#   - TechnicalAgent: next_close=430.3127
# [07:22:40] [MacroAgent] searcher 실행 (데이터셋 준비)
# [OK] MacroAgent searcher - 최신 윈도우 준비 완료: (1, 40, 95)
# [07:22:41] [MacroAgent] 기존 모델 사용: models/TSLA_MacroAgent.pt
# [07:22:41] [MacroAgent] predict 실행
# [07:22:41] [MacroAgent] reviewer_draft 실행
#   |  [INFO] Top 5 features: GC=F_High=8.19e-04, QQQ_Volume=7.19e-04, CL=F_High=7.03e-04, CL=F_Close=6.76e-04, QQQ_High=6.56e-04
# [*********************100%***********************]  1 of 1 completed
#   - MacroAgent: next_close=431.5687
# [07:22:50] [SentimentalAgent] 기존 모델 사용: models/TSLA_SentimentalAgent.pt
# ...

# %%
from agents.sentimental_agent import SentimentalAgent

agent = SentimentalAgent("TSLA")
# searcher를 한 번 호출해서 내부적으로 run_dataset() 수행
_ = agent.searcher("TSLA", rebuild=False)

df_feat = agent.stockdata.raw_df          # run_dataset에서 저장한 원본 피처 DF
cols = df_feat.columns

print("FEATURE_COLS:", cols)
display(df_feat[cols].head(2))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [SentimentalAgent] TSLA 뉴스 수집 시작: 2023-11-30 ~ 2025-11-29
# [SentimentalAgent] 1896개 뉴스 선별 완료 (일자별 최대 3건), 감성 분석 중...
# [SentimentalAgent] Loading FinBERT pipeline on device -1...
# Device set to use cpu
# [SentimentalAgent] 뉴스 DB 업데이트 완료: 1896건
# [SentimentalAgent.run_dataset] missing(before): ['return_1d', 'hl_range', 'Volume']
# [SentimentalAgent.run_dataset] all FEATURE_COLS present.
# [SentimentalAgent.run_dataset] raw features saved to CSV: data/raw/TSLA_SentimentalAgent_raw_features.csv (501 rows, 9 cols)
# FEATURE_COLS: Index(['close', 'high', 'low', 'open', 'volume', 'date', 'count', 'mean',
#        'news_count_1d', 'sentiment_mean_1d', 'news_count_7d',
#        'sentiment_mean_7d', 'sentiment_vol_7d', 'return_1d', 'hl_range',
#        'Volume'],
#       dtype='object')
#         close        high         low        open     volume       date  \
# ...

# %%
from agents.sentimental_agent import SentimentalAgent
from agents.technical_agent import TechnicalAgent
from agents.macro_agent import MacroAgent

agent = SentimentalAgent("TSLA")
# searcher를 한 번 호출해서 내부적으로 run_dataset() 수행
_ = agent.searcher("TSLA", rebuild=False)

df_feat = agent.stockdata.raw_df          # run_dataset에서 저장한 원본 피처 DF
cols = df_feat.columns

print("FEATURE_COLS:", cols)
display(df_feat[cols].head(2))

# %%
import os
import pandas as pd
import torch

from agents.macro_agent import MacroAgent, FINAL_FEATURES
from config.agents import dir_info

ticker = "TSLA"

agent = MacroAgent(ticker=ticker)

# 1) searcher 실행 (데이터 수집 + 파생피처 + CSV 생성 + 최신 윈도우)
X_latest = agent.searcher(ticker=ticker, rebuild=True)  # 첫 실행은 rebuild=True 추천
print("X_latest.shape:", X_latest.shape)   # (1, window, F)

# 2) 피처 개수 / 이름 확인
print("len(FINAL_FEATURES):", len(FINAL_FEATURES))
print("앞 10개 피처:", FINAL_FEATURES[:10])

# 3) CSV 확인 (processed / raw)
data_dir = dir_info["data_dir"]           # 보통 "data/processed"
processed_csv = os.path.join(data_dir, f"{ticker}_MacroAgent_dataset.csv")
raw_csv = os.path.join(os.path.dirname(data_dir), "raw", f"{ticker}_MacroAgent_raw.csv")

print("processed CSV:", processed_csv, "exists:", os.path.exists(processed_csv))
print("raw CSV      :", raw_csv, "exists:", os.path.exists(raw_csv))

df_proc = pd.read_csv(processed_csv)
print("processed shape:", df_proc.shape)
print("processed columns (앞 8개):", df_proc.columns[:8].tolist())

# 4) FINAL_FEATURES와 CSV 피처 일치 여부 체크
csv_features = [c for c in df_proc.columns if c != "Date"]
missing = [f for f in FINAL_FEATURES if f not in csv_features]
extra = [c for c in csv_features if c not in FINAL_FEATURES]

print("CSV 피처 개수:", len(csv_features))
print("CSV에 없는 FINAL_FEATURES 개수:", len(missing))
print("FINAL_FEATURES에 없는 CSV 피처 개수:", len(extra))
# Out:
# [INFO] MacroAgent.searcher: TSLA 매크로 데이터셋/가격 CSV 생성 중...
# [INFO] MacroAgent.searcher: daily_closePrice.csv 저장 완료 (TSLA)
# [INFO] MacroAgent.searcher: 매크로 데이터셋 CSV 저장 완료 -> data/processed/TSLA_MacroAgent_dataset.csv
# [OK] MacroAgent searcher - 최신 윈도우 준비 완료: (1, 40, 95)
# X_latest.shape: torch.Size([1, 40, 95])
# len(FINAL_FEATURES): 95
# 앞 10개 피처: ['CL=F_Close', 'CL=F_High', 'CL=F_Low', 'CL=F_Open', 'CL=F_Volume', 'CL=F_ret_1d', 'DX-Y.NYB_Close', 'DX-Y.NYB_High', 'DX-Y.NYB_Low', 'DX-Y.NYB_Open']
# processed CSV: data/processed/TSLA_MacroAgent_dataset.csv exists: True
# raw CSV      : data/raw/TSLA_MacroAgent_raw.csv exists: True
# processed shape: (502, 96)
# processed columns (앞 8개): ['Date', 'CL=F_Close', 'CL=F_High', 'CL=F_Low', 'CL=F_Open', 'CL=F_Volume', 'CL=F_ret_1d', 'DX-Y.NYB_Close']
# CSV 피처 개수: 95
# CSV에 없는 FINAL_FEATURES 개수: 0
# FINAL_FEATURES에 없는 CSV 피처 개수: 0

# %%
from agents.technical_agent import TechnicalAgent
from agents.macro_agent import MacroAgent
from agents.sentimental_agent import SentimentalAgent

ticker = "TSLA"

tech = TechnicalAgent(ticker=ticker)
macro = MacroAgent(ticker=ticker)
senti = SentimentalAgent(ticker=ticker)

X_tech  = tech.searcher(ticker, rebuild=False)
X_macro = macro.searcher(ticker, rebuild=False)
X_senti = senti.searcher(ticker, rebuild=False)

print("Technical:", X_tech.shape)
print("Macro    :", X_macro.shape)
print("Sentimal :", X_senti.shape)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [OK] MacroAgent searcher - 최신 윈도우 준비 완료: (1, 40, 95)
# [SentimentalAgent] TSLA 뉴스 수집 시작: 2025-11-29 ~ 2025-11-29
# [SentimentalAgent] 새로운 뉴스가 없습니다.
# [SentimentalAgent.run_dataset] missing(before): ['return_1d', 'hl_range', 'Volume']
# [SentimentalAgent.run_dataset] all FEATURE_COLS present.
# [SentimentalAgent.run_dataset] raw features saved to CSV: data/raw/TSLA_SentimentalAgent_raw_features.csv (501 rows, 10 cols)
# Technical: torch.Size([1, 55, 13])
# Macro    : torch.Size([1, 40, 95])
# Sentimal : torch.Size([1, 40, 8])
